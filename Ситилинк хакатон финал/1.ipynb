# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install catboost

# %%
from IPython.display import clear_output
# !wget http://disk.karelia.pro/qEdiHTK/task1.zip?attachment
import os
try:
    os.mkdir("./data")
except: pass
# !unzip "task1.zip?attachment"
clear_output()
# Out:
# --2021-04-03 07:02:14--  http://disk.karelia.pro/qEdiHTK/task1.zip?attachment
# Resolving disk.karelia.pro (disk.karelia.pro)... 93.190.206.138
# Connecting to disk.karelia.pro (disk.karelia.pro)|93.190.206.138|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 281012325 (268M) [application/zip]
# Saving to: ‘task1.zip?attachment.2’
#
# task1.zip?attachmen 100%[===================>] 267.99M  21.7MB/s    in 14s
#
# 2021-04-03 07:02:28 (19.8 MB/s) - ‘task1.zip?attachment.2’ saved [281012325/281012325]
#
# gzip: stdin has more than one entry--rest ignored
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
# Out:
# Archive:  task1.zip?attachment
# caution: filename not matched:  -O
# caution: filename not matched:  data
#
# 1 archive had fatal errors.

# %%
filenames = os.listdir("data")

# %%
filenames
# Out:
# []

# %%
from IPython.display import Image
from IPython.display import display
from IPython.display import clear_output
import os
import time

for name in df[(df["month"] == 3) & (df["hour"].isin([10, 12, 14]))].name:
    print(pd.to_datetime(name[:-4]))
    display(Image(f"./data_resized/{name}"))
    time.sleep(1)
    clear_output()

# %%
df = pd.DataFrame({"dates": os.listdir("data")})
df[~df["dates"].dt.hour.isin(range(6, 24))]

# %%
1 in range(0, 2)
# Out:
# True
